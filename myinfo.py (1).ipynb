# %%
#CS-175-50
#Shuyi Li
#myinfo
print("Shuyi Li")
print("400 Cedar AVE, Long Branch, NJ, 07764")
print("732-666-6666")

print("Data Science")
# Out:
# Shuyi Li
# 400 Cedar AVE, Long Branch, NJ, 07764
# 732-666-6666
# Data Science
